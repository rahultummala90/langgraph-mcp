# %%
# test_bad_code.py
import os

password = "supersecret123"  # hardcoded secret
api_key = "ghp_abc123xyz"    # hardcoded token

def get_user(id):
    query = "SELECT * FROM users WHERE id = " + id  # SQL injection
    return query

def process(data):
    result = eval(data)  # unsafe eval
    return result

def calculate(x, y):
    return x / y  # no division by zero handling
